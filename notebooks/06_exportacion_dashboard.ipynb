# %%
import pandas as pd
from config.paths import REPORTS_DIR, DASHBOARD_DIR, ensure_project_dirs

ensure_project_dirs()

df_dashboard = pd.read_csv(REPORTS_DIR / "dashboard_base.csv")
results_df = pd.read_csv(REPORTS_DIR / "resultados_modelos.csv")

df_dashboard.to_csv(DASHBOARD_DIR / "dataset_dashboard.csv", index=False)
results_df.to_csv(DASHBOARD_DIR / "metricas_modelos.csv", index=False)
